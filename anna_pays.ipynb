# %% [markdown]
# #### Importation du fichier excel + transformer la feuille en fichier .csv + rentrer ce csv dans la variable data + afficher les 5 premières lignes du csv :

# %%
# Importation de la base de donnée
import pandas as pd

# Importer le dichier excel
excel_file = "/Users/annac/Desktop/Projet/Anna_pays.xlsx"

# Lire la feuille Excel
df = pd.read_excel(excel_file)

# Chemin du fichier CSV de sortie
Anna_pays = "/Users/annac/Desktop/Projet/Anna_pays.csv"

# Exporter en CSV
df.to_csv(Anna_pays, index=False)

# Lire le CSV
data = pd.read_csv(Anna_pays)

# Afficher les 5 premières lignes
print(data.head)
# Out:
# <bound method NDFrame.head of                                    Country Quality Score  SDGi  \
# 0                                    Haiti            3A  51.4
# 1                                 Honduras            2B  62.8
# 2                                  Hungary            2A  78.8
# 3                                    India            3A  60.1
# 4                                Indonesia            3A  66.3
# 5                Iran, Islamic Republic of            2A  70.0
# 6                                     Iraq            2A  63.8
# 7                                  Ireland            2A  81.0
# 8                                   Israel            3A  75.0
# 9                                    Italy            3A  78.8
# 10                                 Jamaica            3A  69.0
# 11                                   Japan            3A  79.8
# 12                                  Jordan            3A  70.1
# 13                              Kazakhstan            3A  71.6
# 14                                   Kenya            3A  60.6
# 15  Korea, Democratic People's Republic of            3A   NaN
# 16                      Korea, Republic of            3A  78.6
# 17                                  Kuwait            3A  62.5
# 18                              Kyrgyzstan            2A  74.0
# 19        Lao People's Democratic Republic            3A  63.0
# 20                                  Latvia            3A  79.2
# 21                                 Lebanon            3A  66.8
# 22                                 Lesotho            3A  54.6
# 23                                 Liberia            2A  48.6
# 24                  Libyan Arab Jamahiriya            3A   NaN
# 25                               Lithuania            3A  76.7
# 26                              Luxembourg            3A  74.2
# 27                              Madagascar            3A  49.0
# 28                                  Malawi            3A  51.4
# 29                                Malaysia            3A  70.9
# 30                                    Mali            3A  52.2
# 31                                   Malta            2B  75.7
# 32                              Martinique            2B   NaN
# 33                              Mauritania            2A  55.5
# 34                               Mauritius            2B  66.7
# 35                                  Mexico            3A  69.1
# 36                                Mongolia            3A  63.8
# 37                              Montenegro            3A  68.2
#
#     Life Expectancy    HDI      Per Capita GDP                     Region  \
# 0           63.6600  0.508   1282.238901535785  Central America/Caribbean
# 1           75.0880  0.633   2219.437460402829  Central America/Caribbean
# 2           76.0659  0.850   16894.15400463559                         EU
# 3           69.4160  0.642  2084.8119233498937               Asia-Pacific
# 4           71.5090  0.712   4296.318988609167               Asia-Pacific
# 5           76.4790  0.785   6442.526789263397   Middle East/Central Asia
# 6           70.4540  0.671   5463.968804966208   Middle East/Central Asia
# 7           82.2561  0.951   77406.93104050336                         EU
# 8           82.8024  0.916  36866.823354394364   Middle East/Central Asia
# 9           83.3463  0.890   35277.49798672804                         EU
# 10          74.3680  0.734   4855.273532157433  Central America/Caribbean
# 11          84.2110  0.917   48505.52664266323               Asia-Pacific
# 12          74.4050  0.728  3306.6573844763175   Middle East/Central Asia
# 13          73.1500  0.819   11135.61455216547   Middle East/Central Asia
# 14          66.3420  0.599  1201.4764406294476                     Africa
# 15          72.0950    NaN                   -               Asia-Pacific
# 16          82.6268  0.914   28335.97519991481               Asia-Pacific
# 17          75.3980  0.807   33113.30261927857   Middle East/Central Asia
# 18          71.4000  0.696  1094.1160234110562   Middle East/Central Asia
# 19          67.6100  0.609  1785.5813301256514               Asia-Pacific
# 20          74.7829  0.863  16252.398615921245                         EU
# 21          78.8750  0.747   6204.862959130629   Middle East/Central Asia
# 22          53.7050  0.522  1374.5143751765984                     Africa
# 23          63.7300  0.480   541.2712433800713                     Africa
# 24          72.7240  0.721   8038.589086418168                     Africa
# 25          75.6805  0.876   17744.05082952606                         EU
# 26          82.2951  0.913  111380.64947802795                         EU
# 27          66.6810  0.527   490.0979585607875                     Africa
# 28          63.7980  0.478   515.1098153814952                     Africa
# 29          75.9970  0.805  12116.214158842971               Asia-Pacific
# 30          58.8930  0.431   778.7259789376953                     Africa
# 31          82.4488  0.894   31603.55982841433                         EU
# 32              NaN    NaN                 NaN  Central America/Caribbean
# 33          64.7040  0.542  1703.8636616918193                     Africa
# 34          74.4163  0.801  10561.400120607126                     Africa
# 35          74.9920  0.776  10381.088984158934              North America
# 36          69.6890  0.735   4210.843450411825               Asia-Pacific
# 37          76.7700  0.826   8179.748662821381               Other Europe
#
#    Income Group  Population (millions)  Cropland Footprint  ...  Cropland  \
# 0            LI              11.123200            0.154640  ...  0.154640
# 1            LM               9.587520                 NaN  ...       NaN
# 2            HI               9.707500            1.579887  ...  1.579887
# 3            LM            1352.640000            0.343793  ...  0.343793
# 4            LM             267.671000            0.512431  ...  0.512431
# 5            UM              81.800203            0.347727  ...  0.347727
# 6            LM              38.433602            0.079561  ...  0.079561
# 7            HI               4.818690            0.388758  ...  0.388758
# 8            HI               8.381520            0.102443  ...  0.102443
# 9            HI              60.661898            0.373693  ...  0.373693
# 10           UM               2.934850            0.111248  ...  0.111248
# 11           HI             127.202000            0.084842  ...  0.084842
# 12           UM               9.965320            0.054573  ...  0.054573
# 13           UM              18.319600            1.557377  ...  1.557377
# 14           LI              51.392602            0.200281  ...  0.200281
# 15           LI              25.549600            0.193832  ...  0.193832
# 16           HI              51.171699            0.115834  ...  0.115834
# 17           HI               4.137310            0.021512  ...  0.021512
# 18           LI               6.304030            0.424918  ...  0.424918
# 19           LM               7.061510            0.744427  ...  0.744427
# 20           HI               1.928460            1.315546  ...  1.315546
# 21           UM               6.859410            0.125672  ...  0.125672
# 22           LM               2.108330            0.068916  ...  0.068916
# 23           LI               4.818970            0.139433  ...  0.139433
# 24           UM               6.678560            0.121274  ...  0.121274
# 25           UM               2.801260            1.857192  ...  1.857192
# 26           HI               0.604245            0.296402  ...  0.296402
# 27           LI              26.262301            0.208616  ...  0.208616
# 28           LI              18.143199            0.480071  ...  0.480071
# 29           UM              31.528000            0.721966  ...  0.721966
# 30           LI              19.077699            0.671913  ...  0.671913
# 31           HI               0.439248                 NaN  ...       NaN
# 32          NaN               0.375673                 NaN  ...       NaN
# 33           LM               4.403310            0.109651  ...  0.109651
# 34           UM               1.267190                 NaN  ...       NaN
# 35           UM             126.191000            0.316975  ...  0.316975
# 36           LM               3.170220            0.167473  ...  0.167473
# 37           UM               0.627809            0.063445  ...  0.063445
#
#     Grazing land  Forest land  Fishing ground  Built up land.2  \
# 0       0.029667     0.026424        0.010996         0.024839
# 1            NaN          NaN             NaN              NaN
# 2       0.083131     0.723008        0.006668         0.178949
# 3       0.003092     0.020491        0.026952         0.051241
# 4       0.052133     0.269885        0.344678         0.061119
# 5       0.066210     0.057621        0.181347         0.072263
# 6       0.016075     0.039578        0.002048         0.018913
# 7       0.730523     0.457542        1.418881         0.077060
# 8       0.006077     0.025675        0.014640         0.034361
# 9       0.033288     0.312043        0.060803         0.041642
# 10      0.000000     0.166892        0.107362         0.033178
# 11      0.007452     0.339437        0.099872         0.060490
# 12      0.012390     0.018040        0.002038         0.063610
# 13      1.703415     0.214120        0.050142         0.049396
# 14      0.198418     0.011653        0.015597         0.042731
# 15      0.001440     0.223357        0.091446         0.047718
# 16      0.000841     0.088573        0.383699         0.054793
# 17      0.005486     0.002785        0.291277         0.180293
# 18      0.543429     0.102163        0.047116         0.083750
# 19      0.116995     0.652272        0.030970         0.152222
# 20      0.240059     4.445196        2.062752         0.092117
# 21      0.030436     0.038204        0.004938         0.053908
# 22      0.718018     0.001815        0.000000         0.008083
# 23      0.333555     2.201890        0.279127         0.034710
# 24      0.209921     0.018010        0.234782         0.015264
# 25      0.146038     2.302204        0.320908         0.123577
# 26      0.072450     0.753403        0.000603         0.084863
# 27      1.103992     0.655478        0.180545         0.061678
# 28      0.065685     0.014172        0.048617         0.066612
# 29      0.016964     0.572719        0.779301         0.070183
# 30      0.553319     0.514360        0.038211         0.097460
# 31           NaN          NaN             NaN              NaN
# 32           NaN          NaN             NaN              NaN
# 33      2.512145     0.054254        1.186869         0.058063
# 34           NaN          NaN             NaN              NaN
# 35      0.228654     0.433337        0.132674         0.042964
# 36      7.221815     6.650153        0.078883         0.024100
# 37      0.188679     2.010324        0.239746         0.008851
#
#     Total biocapacity   Ecological (Deficit) or Reserve  \
# 0             0.246566                        -0.390772
# 1             1.736816                         0.162261
# 2             2.571644                        -1.294226
# 3             0.445568                        -0.763988
# 4             1.240246                        -0.476935
# 5             0.725168                        -2.533357
# 6             0.156175                        -1.608156
# 7             3.072763                        -2.178138
# 8             0.183197                        -4.476222
# 9             0.821471                        -3.489062
# 10            0.418680                        -1.215175
# 11            0.592093                        -4.015599
# 12            0.150652                        -1.606404
# 13            3.574450                        -1.376436
# 14            0.468679                        -0.533430
# 15            0.557793                        -0.608395
# 16            0.643739                        -5.673081
# 17            0.501353                        -7.398377
# 18            1.201376                        -0.340176
# 19            1.696885                        -0.143002
# 20            8.155671                         1.750497
# 21            0.253158                        -2.710559
# 22            0.796832                        -0.747311
# 23            2.988714                         1.745752
# 24            0.599251                        -2.681884
# 25            4.749919                        -1.250865
# 26            1.207721                       -11.742638
# 27            2.210309                         1.259256
# 28            0.675157                        -0.205216
# 29            2.161134                        -2.098321
# 30            1.875263                         0.246228
# 31            0.485370                        -4.965859
# 32            0.408065                        -3.085831
# 33            3.920982                         1.404347
# 34            0.667019                        -2.552983
# 35            1.154604                        -1.227858
# 36           14.142425                         6.866709
# 37            2.511045                        -1.717726
#
#     Number of Earths required  Number of Countries required  \
# 0                    0.402710                      2.584860
# 1                    0.994901                      0.906576
# 2                    2.442697                      1.503268
# 3                    0.764273                      2.714638
# 4                    1.085022                      1.384549
# 5                    2.058938                      4.493475
# 6                    1.114814                     11.297145
# 7                    3.317846                      1.708853
# 8                    2.944110                     25.433961
# 9                    2.723662                      5.247335
# 10                   1.032372                      3.902394
# 11                   2.911426                      7.782037
# 12                   1.110217                     11.663044
# 13                   3.128277                      1.385076
# 14                   0.633195                      2.138155
# 15                   0.736870                      2.090718
# 16                   3.991359                      9.812698
# 17                   4.991540                     15.756807
# 18                   0.974048                      1.283155
# 19                   1.162555                      1.084273
# 20                   4.047187                      0.785364
# 21                   1.872661                     11.706992
# 22                   0.975686                      1.937852
# 23                   0.785380                      0.415885
# 24                   2.073225                      5.475394
# 25                   3.791668                      1.263345
# 26                   8.182841                     10.722970
# 27                   0.600934                      0.430281
# 28                   0.556274                      1.303953
# 29                   2.691388                      1.970935
# 30                   1.029325                      0.868697
# 31                   3.444425                     11.231077
# 32                   2.207661                      8.562101
# 33                   1.590166                      0.641838
# 34                   2.034597                      4.827450
# 35                   1.505387                      2.063446
# 36                   4.597249                      0.514460
# 37                   2.672000                      1.684068
#
#     actual \nCountry Overshoot Day \n2018
# 0                                     NaN
# 1                                     NaN
# 2                 1900-05-28 10:12:01.909
# 3                                     NaN
# 4                 1900-12-01 09:34:17.720
# 5                 1900-06-25 06:37:11.695
# 6                 1900-11-22 09:48:48.243
# 7                 1900-04-19 00:16:02.384
# 8                 1900-05-02 23:25:56.027
# 9                 1900-05-13 00:15:28.066
# 10                1900-12-18 13:19:00.353
# 11                1900-05-04 08:50:04.453
# 12                1900-11-23 18:20:56.800
# 13                1900-04-25 16:15:48.303
# 14                                    NaN
# 15                                    NaN
# 16                1900-03-31 10:44:27.982
# 17                1900-03-13 02:58:09.717
# 18                                    NaN
# 19                1900-11-08 23:07:43.429
# 20                1900-03-30 04:27:59.364
# 21                1900-07-12 21:50:10.962
# 22                                    NaN
# 23                                    NaN
# 24                1900-06-24 01:18:06.682
# 25                1900-04-05 06:19:42.878
# 26                1900-02-13 14:31:58.094
# 27                                    NaN
# 28                                    NaN
# 29                1900-05-14 14:49:34.524
# 30                1900-12-19 14:25:46.332
# 31                1900-04-14 23:14:25.034
# 32                1900-06-13 08:00:04.222
# 33                1900-08-16 12:51:26.001
# 34                1900-06-27 09:31:11.813
# 35                1900-08-29 11:05:59.516
# 36                1900-03-19 09:29:14.545
# 37                1900-05-15 14:26:34.259
#
# [38 rows x 33 columns]>

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

df_subset = df[(df["Country"] >= "Haiti") & (df["Country"] <= "Montenegro")]
len(df_subset)

# Matrice binaire : 1 = NA, 0 = pas NA
na_matrix = df_subset.isna().astype(int).values

# Palette binaire : blanc = 0, rouge = 1
cmap = mcolors.ListedColormap(["white", "red"])

# %%
plt.figure(figsize=(14, 10))

# Heatmap
plt.imshow(na_matrix, cmap=cmap, aspect="auto")

# --- Axe X : noms des colonnes ---
plt.xticks(
    ticks=np.arange(len(df.columns)),
    labels=df_subset.columns,
    rotation=90
)

# --- Axe Y : noms des pays ---
plt.yticks(
    ticks=np.arange(len(df_subset)),
    labels=df_subset["Country"],
    fontsize=6
)

# --- Quadrillage ---
plt.grid(color='black', linestyle='-', linewidth=0.3)

# Ajuster le quadrillage pour qu’il s’aligne sur les cellules
plt.gca().set_xticks(np.arange(-0.5, len(df_subset.columns), 1), minor=True)
plt.gca().set_yticks(np.arange(-0.5, len(df_subset), 1), minor=True)
plt.grid(which='minor', color='black', linestyle='-', linewidth=0.3)
plt.grid(False)  # enlève la grille principale, garde la fine

plt.colorbar(label="1 = NA (rouge), 0 = pas NA (blanc)")
plt.title("Heatmap des données manquantes (NA) avec quadrillage")

plt.tight_layout()
plt.show()

# %%
var_x = "Var1"
var_y = "Var2"

plt.figure(figsize=(8,6))
plt.hist2d(df_subset[var_x], df_subset[var_y], bins=20)
plt.colorbar(label="Densité")
plt.xlabel(var_x)
plt.ylabel(var_y)
plt.title(f"Histogramme 2D — {var_x} vs {var_y}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\annac\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Var1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       2 var_y = "Var2"
#       4 plt.figure(figsize=(8,6))
# ----> 5 plt.hist2d(df_subset[var_x], df_subset[var_y], bins=20)
#       6 plt.colorbar(label="Densité")
#       7 plt.xlabel(var_x)
#
# File c:\Users\annac\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\annac\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Var1'
